# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
image = cv2.imread('C:/Users/burak/Desktop/sample.jpg')
c = 255 / np.log(1 + np.max(image))
log_image = c * (np.log(image + 1))
log_image = np.array(log_image, dtype=np.uint8)
plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1), plt.imshow(image)
plt.title('Orginal')
plt.subplot(1, 2, 2), plt.imshow(log_image)
plt.title('Log')
plt.show()
# Out:
# C:\Users\burak\AppData\Local\Temp\ipykernel_2944\946220238.py:6: RuntimeWarning: divide by zero encountered in log
#   log_image = c * (np.log(image + 1))
